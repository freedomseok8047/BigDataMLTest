# %% [markdown]
# ### 결정트리 분석, 시각화 산점도, 선형회귀 그래프 이용할 예정
# #### 결정트리 시각화 (다른 프로그램 설치해야함)
# #### 샘플 데이터, 센서 데이터의 움직임 수집한 데이터
# #### UCI 대학의 연구원들이 몸에 센서달고 몇일 간 생활하면서 수집
# #### 움직임 판단 -> 서기 ,눕기, 계단 오르기 등등

# %% [markdown]
# ### 용어정리
# #### 결정트리 : 머신러닝 알고리즘 중에 하나이고, 다중 분류를 하는데 많이 사용함
# #### 스스로 데이터 안에 특정 규칙을 찾아서 학습하고 ,트리구조 분류 규칙을 만든다.
# #### 규칙노드, 리프노드(결정노드)
# #### 예) 날개가 있나요? : 규칙노드
# ####            /            \
# ####      날 수 있니?      털이있니? : 규칙노드
# ####      /T     \F        /T     \F
# ####   참새      팽귄     다람쥐   개구리 : 결정노드
#
# #### 정보이득지수 : 엔트로피 (entropy) 개념을 기반으로 함
# #### 엔트로피 : 데이터 집합의 혼잡도를 의미
# #### 예) 데이터에 다른 데이터가 섞여서 균일도가 떨어지면 -> 혼잡도가 높다 -> 엔트로피 높다
# #### 정보이득지수 = 1 - 엔트로피
# #### 엔트로피 높다 -> 정보이득 지수 낮다 -> 데이터 순수도 떨어짐 (다른 데이터들이 섞여 있다)
# #### 엔트로피 낮다 -> 정보이득 지수 높다 -> 데이터 균일도 높다 (다른 데이터들이 섞여 있지 않다)
#
# #### 지니계수 : 경제학 용어이고, 소득의 불균형의 정도를 나타낼때 사용 -> 우리는 데이터의 순도를 나타낼때 사용
# #### 지니계수 높다 -> 순도가 낮은 데이터 집합이다 -> 균일도가 낮다 -> 엔트로피 높다 -> 다른데이터들 많이 섞였다.
# #### 지니계수 낮다 -> 순도 높다
#
#
# #### 사이킷 런에서 제공하는 결정 트리 분류 모델의 매개변수
# #### min_samples_split : 노드를 분할하기 위한 최소 샘플 데이터 갯수 (기본값 : 2)
# #### min_samples_leaf : 리프노드가 되기 위한 최소 샘플 데이터 갯수
# #### max_features : 최적의 분할을 하기위해 고려해야할 최대 피처 갯수 (예 독립변수)
# #### None : 모든 피처 사용, int: 사용할 피쳐의 갯수,
# #### float : 사용할 피처 갯수를 퍼센트
# #### sqrt : 루트 계산
#
# #### max_depth : 트리의 최대깊이
# #### max_leaf_nodes : 리프노드(결정노드)에 들어가는 샘플의 최대 데이터 갯수
# #### Graphviz 패키지 : 결정 트리를 시각화 하는 도구.
